# %% [markdown]
# # Datasets - from EDI to jrn_metabase
#
# Below are some tests for populating JRN Metabase from EDI using python. The basic idea is to pull metadata from JRN packages in EDI using the PASTA+ API, arrange that into a pandas dataframe, and then insert that metadata into JRN Metabase using psycopg2. It works best if the pandas dataframe matches the JRN Metabase tables being copied to.

# %%
import sys
sys.path.append('/home/greg/GitHub/')
import pyEDIutils.search as edi
import pandas as pd
import numpy as np

# %% [markdown]
# ## Create a DataSets table

# %%
# Query edi for all data packages in jrn scope

#import importlib
#importlib.reload(edi)
df = edi.request_search(fields=['packageid','title','pubdate','keyword','author',
                                   'begindate','enddate','doi'],
                        rows=1000)
# Out:
# https://pasta.lternet.edu/package/search/eml?defType=edismax&q=%2A&fq=scope%3Aknb-lter-jrn&fl=packageid%2Ctitle%2Cpubdate%2Ckeyword%2Cauthor%2Cbegindate%2Cenddate%2Cdoi&sort=packageid%2Casc&rows=1000

# %%
df.head()
# Out:
#                     packageid  \
# 0          knb-lter-jrn.100.3
# 1   knb-lter-jrn.210001001.62
# 2   knb-lter-jrn.210001002.76
# 3   knb-lter-jrn.210001003.79
# 4  knb-lter-jrn.210002001.127
#
#                                                title pubdate  \
# 0  High resolution shrub cover raster maps of the...    2020
# 1  Plant cover on 2 x 2 meter rainfall runoff plo...    2020
# 2  Rainfall runoff and sediment deposition from 2...    2019
# 3  Rainfall runoff water chemistry from 2 x 2 met...    2020
# 4  Graduated rain gauge (GRG) precipitation obser...    2019
#
#                                             keywords  \
# 0  canopy cover;land surface properties;plant cov...
# 1  termites;runoff;plant cover;deserts;grasslands...
# 2  land cover;runoff;plant communities;deserts;gr...
# 3  termites;runoff;chemical properties;deserts;gr...
# 4  precipitation;climate;rain;hydrological proces...
#
#                                         authors   begindate     enddate  \
# 0                    Ji, Wenjie;Hanan, Niall P.  2011-01-01  2011-12-31
# 1  Ward, Tim;Bolton, Susan;Schlesinger, William  1989-10-27  1990-10-19
# 2                                     Ward, Tim  1982-09-09  1994-10-15
# 3  Ward, Tim;Bolton, Susan;Schlesinger, William  1988-06-27  1990-09-11
# 4                Huenneke, Laura;Anderson, John  1989-01-03  2019-04-16
#
#                                                  doi
# 0  doi:10.6073/pasta/313fec8669bc7b4d8debf7393dd2...
# 1  doi:10.6073/pasta/d320f815d3183ea09fa2f18e0030...
# 2  doi:10.6073/pasta/a6b6175f8a064fe2bd35a62e2de0...
# 3  doi:10.6073/pasta/db814c25fb4bf8f6bdd7addbbcbd...
# 4  doi:10.6073/pasta/39920e433f27d19f0c196d431a4a...

# %%
# Split the dataset id and revisions out
df[['scope', 'datasetid', 'revision']] = df['packageid'].str.split('.',expand=True)

# %%
# Format the dataframe to look like the DataSet table in jrn_metabase
df['abstract'] = 'abstract.docx'
df['updatefrequency'] = 'notPlanned'
df['maintenancedesc'] = ''
df['abstracttype'] = 'file'
df['boilerplate'] = 'default'
df['shortname'] = ''

# %%
# Remove the met packages John/geovany use
import numpy as np
nonmet1 = ~df['datasetid'].str.contains('210437')
nonmet2 = ~df['datasetid'].str.contains('210548')
nonmet = np.logical_and(nonmet1, nonmet2)
nonmet.sum()
# Out:
# 117

# %%
# Rearrange columns
ds_in = df.loc[nonmet,['datasetid','revision','title','pubdate','abstract','shortname','updatefrequency','maintenancedesc','abstracttype','boilerplate']]

# %%
# Reformat dates in pubdate
ds_in.pubdate = ds_in.pubdate + '-12-31'
ds_in.head()
# Out:
#    datasetid revision                                              title  \
# 0        100        3  High resolution shrub cover raster maps of the...
# 1  210001001       62  Plant cover on 2 x 2 meter rainfall runoff plo...
# 2  210001002       76  Rainfall runoff and sediment deposition from 2...
# 3  210001003       79  Rainfall runoff water chemistry from 2 x 2 met...
# 4  210002001      127  Graduated rain gauge (GRG) precipitation obser...
#
#       pubdate       abstract shortname updatefrequency maintenancedesc  \
# 0  2020-12-31  abstract.docx                notPlanned
# 1  2020-12-31  abstract.docx                notPlanned
# 2  2019-12-31  abstract.docx                notPlanned
# 3  2020-12-31  abstract.docx                notPlanned
# 4  2019-12-31  abstract.docx                notPlanned
#
#   abstracttype boilerplate
# 0         file     default
# 1         file     default
# 2         file     default
# 3         file     default
# 4         file     default

# %%
ds_in.shape
ds_in[ds_in.datasetid=='210351004']
# Out:
#     datasetid revision                                              title  \
# 73  210351004        2  Quadrat-based monitoring of desert grassland v...
#
#        pubdate       abstract shortname updatefrequency maintenancedesc  \
# 73  2021-12-31  abstract.docx                notPlanned
#
#    abstracttype boilerplate
# 73         file     default

# %% [markdown]
# ## Create a data entity table

# %%
# direct api calls
import pyEDIutils.pkginfo as edi2

# %%
ent = edi2.entity_table('knb-lter-jrn', '210011002', '106')
ent
# Out:
# https://pasta.lternet.edu/package/name/eml/knb-lter-jrn/210011002/106
# https://pasta.lternet.edu/package/data/rmd/eml/knb-lter-jrn/210011002/106/d6dca3385347d23e7b94d59a0ae15ffa
# https://pasta.lternet.edu/package/data/rmd/eml/knb-lter-jrn/210011002/106/ffdbf923e4b116d81156c18af0301ef2
#                            entityid  \
# 0  d6dca3385347d23e7b94d59a0ae15ffa
# 1  ffdbf923e4b116d81156c18af0301ef2
#
#                                           entityname  \
# 0  Plant dimensions (cover, height) collected by ...
# 1  Field protocol for non-destructive quadrat mea...
#
#                     packageid  datasetid  entityorder  \
# 0  knb-lter-jrn.210011002.106  210011002            1
# 1  knb-lter-jrn.210011002.106  210011002            2
#
#                                         filename   entitytype filetype
# 0                JRN_011002_npp_quadrat_meas.csv    dataTable    csv_D
# 1  nppfield_protocol_master_for-distribution.pdf  otherEntity     None

# %%
ds_in.tail()
# Out:
#      datasetid revision                                              title  \
# 112  210425001       75  Gap-filled daily precipitation at the 15 long-...
# 233  210461001       17  Perennial grass recovery following livestock o...
# 234  210472001        1  Vegetation cover and Soil Organic Carbon along...
# 235  210493001        1  Biotic and abiotic composition of biological s...
# 236  210520001        1  Vascular Plant Species of the Jornada Basin, 1...
#
#         pubdate       abstract shortname updatefrequency maintenancedesc  \
# 112  2020-12-31  abstract.docx                notPlanned
# 0        Soil crust microfauna counts, 2017-2018   knb-lter-jrn.210493001.1
# 1                Soil crust PLFA data, 2017-2018   knb-lter-jrn.210493001.1
# 2                Soil properties data, 2017-2018   knb-lter-jrn.210493001.1
# 0            JRN vascular plant species list.csv   knb-lter-jrn.210520001.1
#
#     datasetid  entityorder                                        filename  \
# 0         100            1               JER_CDRRC_shrubcover_2011_1ha.tif
# 1         100            2                   JER_CDRRC_shrubcover_2011.tif
# 0   210001001            1           JRN_001001_runoff_vegetation_data.csv
# 1   210001001            2                              Hydrology_prog.txt
# 0   210001002            1                 JRN_001002_Hydrology_Runoff.csv
# ..        ...          ...                                             ...
# 1   210472001            2                   Cattle_soil_carbon_figure.jpg
# 0   210493001            1  JRN_493001_soilcrust_microfauna_count_data.csv
# 1   210493001            2   JRN_493001_soilcrust_microflora_plfa_data.csv
# 2   210493001            3          JRN_493001_soilcrust_soilprop_data.csv
# 0   210520001            1             JRN vascular plant species list.csv
#
#      entitytype filetype
# 0   otherEntity
# 1   otherEntity
# 0     dataTable    csv_D
# 1   otherEntity
# 0     dataTable    csv_D
# ..          ...      ...
# 1   otherEntity
# 0     dataTable    csv_D
# 1     dataTable    csv_D
# 2     dataTable    csv_D
# 0     dataTable    csv_D
#
# [246 rows x 8 columns]

# %%
ent_out['entitydesc'] = 'Add description'
ent_in = ent_out.loc[:, ['datasetid','entityorder','entityname','entitytype',
                         'entitydesc','filetype','filename']]
ent_in.head()
# Out:
#    datasetid  entityorder                                    entityname  \
# 0        100            1             JER_CDRRC_shrubcover_2011_1ha.tif
# 1        100            2                 JER_CDRRC_shrubcover_2011.tif
# 0  210001001            1                               Plant cover csv
# 1  210001001            2                 Detailed procedures text file
# 0  210001002            1  Rainfall runoff and sediment deposition data
#
#     entitytype       entitydesc filetype  \
# 0  otherEntity  Add description
# 1  otherEntity  Add description
# 0    dataTable  Add description    csv_D
# 1  otherEntity  Add description
# 0    dataTable  Add description    csv_D
#
#                                 filename
# 0      JER_CDRRC_shrubcover_2011_1ha.tif
# 1          JER_CDRRC_shrubcover_2011.tif
# 0  JRN_001001_runoff_vegetation_data.csv
# 1                     Hydrology_prog.txt
# 0        JRN_001002_Hydrology_Runoff.csv

# %%
ent_in.entityname.iloc[164]
# Out:
# 'Soil Particle Size Analysis and Sand Fractionation data at Permanent Quadrat locations, Jornada Experimental Range, 2001-2020'

# %%
# Some too-long names
ent_in.entityname.iloc[114] = 'Rodent capture data across grass-shrub ecotones at 3 sites, 2004-ongoing'
ent_in.entityname.iloc[115] = 'Rodent abundance and biomass data across grass-shrub ecotones at 3 sites, 2004-ongoing'
ent_in.entityname.iloc[119] = 'Plant phenology observations at 15 net primary production (NPP) study sites, 1992-ongoing'
ent_in.entityname.iloc[150] = 'Aboveground Net Primary Production (g/m2) by plant functional group under precip treatments'
ent_in.entityname.iloc[160] = 'Basal Cover of Perennial Grasses and Canopy Cover of Shrubs at JER Permanent Quadrats, 1915-ongoing'
ent_in.entityname.iloc[162] = 'Plant Density of Perennial Forbs and Subshrubs at JER Permanent Quadrats, 1915-ongoing'
ent_in.entityname.iloc[164] = 'Soil Particle Size Analysis and Sand Fractionation data at JER Permanent Quadrats, 2001-2020'
# Out:
# /home/greg/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Now insert the tables

# %%
# Establish database connection
sys.path.append('../')
import py2pg.connect as connect
conn = connect.connect('../jrn_metabase_dev.conn.json')

# %%
# Do a test query of the database
sql = 'select * from lter_metabase."DataSet";'
dat = pd.read_sql_query(sql, conn)

# %%
dat.head()
# Out:
#    DataSetID  Revision                                              Title  \
# 0      99013        21    SBC LTER: TEST: Water temperature at the bottom
# 1      99021        11          SBC LTER: TEST: NPP dataset with 3 tables
# 2      99024        17                           SBC LTER: TEST: kelp CHN
# 3      99054         4  SBC LTER: TESTOLEUM: Giant kelp canopy biomass...
# 4  210011002       106  Seasonal non-destructive vegetation measuremen...
#
#       PubDate             Abstract                      ShortName  \
# 0  2019-08-07  abstract.99013.docx  Reef bottom water temperature
# 1  2016-09-08  abstract.99021.docx         Beach wrack IV 2005-06
# 2  2019-01-15  abstract.99024.docx   Kelp - algal weights and CHN
# 3  2014-01-14  abstract.99054.docx  Satellite kelp canopy biomass
# 4  2019-12-31        abstract.docx
#
#   UpdateFrequency                             MaintenanceDescription  \
# 0        annually                               Ongoing time series.
# 1      notPlanned  Completed timeseries. No future data updates a...
# 2        annually  Ongoing time series. Data updates may be delay...
# 3      notPlanned  Completed timeseries. No future data updates a...
# 4      notPlanned
#
#   AbstractType BoilerplateSetting
# 0         file            default
# 1         file            default
# 2         file            default
# 3         file            default
# 4         file            default

# %%
import py2pg.populate as pop

# %%
# Use the function to load ds_in (from EDI) into the DataSet 
# table in jrn_metabase. Errors will be printed here if the 
# copy operation can't be completed.
pop.copy_from_file(conn, ds_in[ds_in.datasetid=='210351004'], 'lter_metabase."DataSet"') # copy the dataframe to SQL
# Close the database connection
#conn.close()
# Out:
# > /home/greg/GitHub/lter_metabase_utils/py2pg/populate.py(26)copy_from_file()
#      24     df.to_csv(tmp_df, index=False, sep=';', header=False)
#      25     pdb.set_trace()
# ---> 26     f = open(tmp_df, 'r')
#      27     cursor = conn.cursor()
#      28     try:
# ipdb>  c
# copy_from_file() done

# %%
import importlib
importlib.reload(pop)
pop.copy_from_file(conn, ent_in, 'lter_metabase."DataSetEntities"',
                   columns=('"DataSetID"','"EntitySortOrder"','"EntityName"','"EntityType"',
                            '"EntityDescription"','"FileType"','"FileName"')) # copy the dataframe to SQL
# Close the database connection
conn.close()
# Out:
# Error: duplicate key value violates unique constraint "PK_DataSetEntities"
# DETAIL:  Key ("DataSetID", "EntityName")=(100, JER_CDRRC_shrubcover_2011_1ha.tif) already exists.
# CONTEXT:  COPY DataSetEntities, line 1
