# %% [markdown]
# # Datasets Site info - from EDI to jrn_metabase
#
# Code for populating the DataSetSites table in jrn_metabase is below. The EDI Solr search
# API is a little wonky in that when site data, including geographic descriptions and
# coordinates queries, are requested the response doesn't contain everything in the EML.
# Requesting geographic description will only return the geographicDescription element from the _first_ geographicCoverage found even if there are multiple geographicCoverages. If requesting coordinates, all boundingCoordinates elements found within the coverage element are returned. So, it makes sense to just count the spatial elements returned per datasetID.

# %%
import sys
sys.path.append('/home/greg/GitHub/')
import pyEDIutils.search as edi
import pandas as pd
import numpy as np

# %% [markdown]
# ## Create a DataSets table with site/spatial info

# %%
# Query edi for all data packages in jrn scope and include spatial data
import importlib
importlib.reload(edi)
importlib.reload(edi.rq)
df, root = edi.request_search(fields=['packageid','title', 'site',
                                      'geographicdescription', 'coordinates'],
                              rows=1000, returnroot=True)
# Out:
# https://pasta.lternet.edu/package/search/eml?defType=edismax&q=%2A&fq=scope%3Aknb-lter-jrn&fl=packageid%2Ctitle%2Csite%2Cgeographicdescription%2Ccoordinates&sort=packageid%2Casc&rows=1000
# More than 1 spatial entity per packageid, so just counting

# %%
df.head()
# Out:
#                     packageid  \
# 0          knb-lter-jrn.100.3
# 1   knb-lter-jrn.210001001.62
# 2   knb-lter-jrn.210001002.76
# 3   knb-lter-jrn.210001003.79
# 4  knb-lter-jrn.210002001.127
#
#                                                title site  \
# 0  High resolution shrub cover raster maps of the...  jrn
# 1  Plant cover on 2 x 2 meter rainfall runoff plo...  jrn
# 2  Rainfall runoff and sediment deposition from 2...  jrn
# 3  Rainfall runoff water chemistry from 2 x 2 met...  jrn
# 4  Graduated rain gauge (GRG) precipitation obser...  jrn
#
#                                geographicdescription  coordinates_ent
# 0  This spatial dataset covers the Jornada Experi...                1
# 1  Creosotebush plots (C) located in the west baj...                2
# 2  Creosotebush plots (C) located in the west baj...                2
# 3  Creosotebush plots (C) located in the west baj...                2
# 4  NPP is measured at 15 sites, spanning 5 vegeta...                1

# %%
# Split the dataset id and revisions out
df[['scope', 'datasetid', 'revision']] = df['packageid'].str.split('.',expand=True)
# Empty column for SiteID
df['SiteID'] = ''
len(df)
# Out:
# 340

# %%
# Remove the met packages John/geovany use
import numpy as np
nonmet1 = ~df['datasetid'].str.contains('210437')
nonmet2 = ~df['datasetid'].str.contains('210548')
nonmet = np.logical_and(nonmet1, nonmet2)
df = df[nonmet]
len(df)
# Out:
# 117

# %%
# For "None" geographic descriptins, assign a Headquarters siteID
df.loc[df.geographicdescription.isna(), 'SiteID'] = 'HQ_unspecified'
df.loc[df.geographicdescription.isna(), 'geographicdescription'] = 'HQ_unspecified'

# %%
# Match patterns in the geographic description to assign SiteIDs
test1 = df.geographicdescription.str.contains('west bajada', case=False)
test2 = df.geographicdescription.str.contains('bajada_west', case=False)
test3 = df.geographicdescription.str.contains('bajada west', case=False)
test = test1 | test2 |test3
df.loc[test, 'SiteID'] = 'Bajada_West'
test1 = df.geographicdescription.str.contains('east bajada', case=False)
test2 = df.geographicdescription.str.contains('bajada_east', case=False)
test = test1 | test2
df.loc[test, 'SiteID'] = 'Bajada_East'
test1 = df.geographicdescription.str.contains('basin floor', case=False)
test2 = df.geographicdescription.str.contains('basin_floor', case=False)
test = test1 | test2
df.loc[test, 'SiteID'] = 'Basin_Floor'
test1 = df.geographicdescription.str.contains('sand sheet', case=False)
test2 = df.geographicdescription.str.contains('sand_sheet', case=False)
test = test1 | test2
df.loc[test, 'SiteID'] = 'Sand Sheet'
test1 = df.geographicdescription.str.contains('transition', case=False)
df.loc[test1, 'SiteID'] = 'Transition_Zone'
test1 = df.geographicdescription.str.contains('NPP', case=False)
df.loc[test1, 'SiteID'] = 'NPP_Sites'
# We know what to call this one
test = df.datasetid=='100'
df.loc[test, 'SiteID'] = 'shrub_cover_raster_pkg100'

# %% [markdown]
# ## What hasn't been identified?

# %%
df[df.SiteID=='']
# Out:
#                       packageid  \
# 8     knb-lter-jrn.210010001.75
# 20    knb-lter-jrn.210015002.44
# 21    knb-lter-jrn.210015003.48
# 34    knb-lter-jrn.210121001.47
# 36    knb-lter-jrn.210121006.67
# 39   knb-lter-jrn.210126001.113
# 45     knb-lter-jrn.210262001.8
# 46    knb-lter-jrn.210262004.93
# 47     knb-lter-jrn.210262005.9
# 48   knb-lter-jrn.210262008.139
# 49    knb-lter-jrn.210262010.88
# 54    knb-lter-jrn.210301001.56
# 55    knb-lter-jrn.210301002.77
# 62     knb-lter-jrn.210327001.1
# 70    knb-lter-jrn.210351001.49
# 71    knb-lter-jrn.210351002.77
# 72     knb-lter-jrn.210351003.3
# 73     knb-lter-jrn.210351004.2
# 75    knb-lter-jrn.210368001.40
# 76    knb-lter-jrn.210368002.29
# 77    knb-lter-jrn.210368003.37
# 78    knb-lter-jrn.210368004.32
# 82    knb-lter-jrn.210379001.80
# 83    knb-lter-jrn.210379002.61
# 84    knb-lter-jrn.210379003.63
# 85   knb-lter-jrn.210380001.738
# 105    knb-lter-jrn.210407001.5
# 107   knb-lter-jrn.210409001.62
# 109   knb-lter-jrn.210412001.58
# 110    knb-lter-jrn.210420001.1
# 111    knb-lter-jrn.210420002.1
# 233   knb-lter-jrn.210461001.17
# 234    knb-lter-jrn.210472001.1
# 236    knb-lter-jrn.210520001.1
#
#                                                  title site  \
# 8    Termite foraging data from bait mass loss at e...  jrn
# 20      Transect Soil Mineralization Potential (Field)  jrn
# 21    Transect Soil Mineralization Potential (Initial)  jrn
# 34             Biodiversity plots vegetation transects  jrn
# 36   The Effects of Changing Vegetative Composition...  jrn
# 39     LTER Weather Station daily summary climate data  jrn
# 45   Spring and Fall plant cover across grassland-s...  jrn
# 46   Annual Aboveground Net Primary Productivity by...  jrn
# 47   Total Annual Aboveground Net Primary Productiv...  jrn
# 48   Rodent capture data across grassland-shrubland...  jrn
# 49   Rodent abundance and biomass data across grass...  jrn
# 54   Aggregate mesquite litter chemistry following ...  jrn
# 55   Aggregate mesquite litter mass following soil-...  jrn
# 62   Greenfall litter decomposition of three common...  jrn
# 70   Plant Cover at Permanent Quad Locations on the...  jrn
# 71   Plant Density at Permanent Quad Locations on t...  jrn
# 72   Soil Particle Size Analysis at Permanent Quadr...  jrn
# 73   Quadrat-based monitoring of desert grassland v...  jrn
# 75           Density and cover of winter annual plants  jrn
# 76                             Ant nest soil nutrients  jrn
# 77                        Ant nest soil organic matter  jrn
# 78                         Ant nest soil water content  jrn
# 82   Daily temperature and precipitation data from ...  jrn
# 83   Monthly summary temperature and precipitation ...  jrn
# 84   Monthly evaporation data from a NOAA evaporati...  jrn
# 85   Monthly precipitation data from a network of s...  jrn
# 105  Daily precipitation from a network of weighing...  jrn
# 107  Photosynthetic rates for leaves from 5 precipi...  jrn
# 109  Jornada Experimental Range (USDA-ARS) annual s...  jrn
# 110  Soil carbon, soil nitrogen, and geometry of 30...  jrn
# 111  Soil water and chloride concentration profiles...  jrn
# 233  Perennial grass recovery following livestock o...  jrn
# 234  Vegetation cover and Soil Organic Carbon along...  jrn
# 236  Vascular Plant Species of the Jornada Basin, 1...  jrn
#
#                                  geographicdescription  coordinates_ent  \
# 8    The consumer site are located at 11 sites acro...                1
# 20   Our study site is located in the northern Chih...                1
# 21   Our study site is located in the northern Chih...                1
# 34   Our study site is located in the northern Chih...                1
# 36   Our study site is located in the northern Chih...                1
# 39   Our study site is located in the northern Chih...                1
# 45   Pastures 9 and 12A of the Jornada Experimental...                1
# 46   Pastures 9 and 12A of the Jornada Experimental...                1
# 47   Pastures 9 and 12A of the Jornada Experimental...                1
# 48   Pastures 9 and 12A of the Jornada Experimental...                1
# 49   Pastures 9 and 12A of the Jornada Experimental...                1
# 54   Our study site is located in the northern Chih...                1
# 55   Our study site is located in the northern Chih...                1
# 62     Jornada Basin, Dona Ana County, New Mexico, USA                1
# 70   Jornada Experimental Range, Dona Any County, N...                1
# 71   Jornada Experimental Range, Dona Any County, N...                1
# 72   Jornada Experimental Range, Dona Any County, N...                1
# 73   "Jornada Experimental Range, Dona Ana County, ...                1
# 75   Our study site is located in the northern Chih...                1
# 76   Our study site is located in the northern Chih...                1
# 77   Our study site is located in the northern Chih...                1
# 78   Our study site is located in the northern Chih...                1
# 82   The NWS weather station is located at USDA JER...                1
# 83   The NWS weather station is located at USDA JER...                1
# 84   The evaporation pan was located at USDA JER He...                1
# 85   "Jornada Experimental Range, Dona Ana County, ...                1
# 105  USDA-ARS Jornada Experimental Range, Dona Ana ...                1
# 107  Our study site is located in the northern Chih...                1
# 109                                       JER pastures                1
# 110  Playas in this study are distributed across th...                1
# 111  Playas in this study are distributed across th...                1
# 233  Pasture 9, Jornada Experimental Range, Dona An...                1
# 234  Headquarters cattle drinker, Jornada Basin, Do...                3
# 236    Jornada Basin, Dona Ana County, New Mexico, USA                1
#
#             scope  datasetid revision SiteID
# 8    knb-lter-jrn  210010001       75
# 20   knb-lter-jrn  210015002       44
# 21   knb-lter-jrn  210015003       48
# 34   knb-lter-jrn  210121001       47
# 36   knb-lter-jrn  210121006       67
# 39   knb-lter-jrn  210126001      113
# 45   knb-lter-jrn  210262001        8
# 46   knb-lter-jrn  210262004       93
# 47   knb-lter-jrn  210262005        9
# 48   knb-lter-jrn  210262008      139
# 49   knb-lter-jrn  210262010       88
# 54   knb-lter-jrn  210301001       56
# 55   knb-lter-jrn  210301002       77
# 62   knb-lter-jrn  210327001        1
# 70   knb-lter-jrn  210351001       49
# 71   knb-lter-jrn  210351002       77
# 72   knb-lter-jrn  210351003        3
# 73   knb-lter-jrn  210351004        2
# 75   knb-lter-jrn  210368001       40
# 76   knb-lter-jrn  210368002       29
# 77   knb-lter-jrn  210368003       37
# 78   knb-lter-jrn  210368004       32
# 82   knb-lter-jrn  210379001       80
# 83   knb-lter-jrn  210379002       61
# 84   knb-lter-jrn  210379003       63
# 85   knb-lter-jrn  210380001      738
# 105  knb-lter-jrn  210407001        5
# 107  knb-lter-jrn  210409001       62
# 109  knb-lter-jrn  210412001       58
# 110  knb-lter-jrn  210420001        1
# 111  knb-lter-jrn  210420002        1
# 233  knb-lter-jrn  210461001       17
# 234  knb-lter-jrn  210472001        1
# 236  knb-lter-jrn  210520001        1

# %%
# Assign these to Headquarters too...
df.loc[df.SiteID=='', 'SiteID'] = 'HQ_unspecified'

# %% [markdown]
# ## For datasets with >1 geographicCoverage
#
# We counted coordinate entities, now we need to duplicate the rows for datasets > 1 and
# concatenate them onto the dataframe again.

# %%
# These datsets have multiple geoCoverages
mults = df.coordinates_ent > 1
df_rep = df[mults].copy() # Copy the rows
df_rep.SiteID = 'Unknown_placeholder' # Assign a placeholder (in DB) to fill in later
df_rep.head()
# Out:
#                      packageid  \
# 1    knb-lter-jrn.210001001.62
# 2    knb-lter-jrn.210001002.76
# 3    knb-lter-jrn.210001003.79
# 14  knb-lter-jrn.210012001.139
# 15  knb-lter-jrn.210012002.127
#
#                                                 title site  \
# 1   Plant cover on 2 x 2 meter rainfall runoff plo...  jrn
# 2   Rainfall runoff and sediment deposition from 2...  jrn
# 3   Rainfall runoff water chemistry from 2 x 2 met...  jrn
# 14  Raw neutron counts from a soil water content h...  jrn
# 15  Soil volumetric water content calculated from ...  jrn
#
#                                 geographicdescription  coordinates_ent  \
# 1   Creosotebush plots (C) located in the west baj...                2
# 2   Creosotebush plots (C) located in the west baj...                2
# 3   Creosotebush plots (C) located in the west baj...                2
# 14                                        Bajada_West                2
# 15                                        Bajada_West                2
#
#            scope  datasetid revision               SiteID
# 1   knb-lter-jrn  210001001       62  Unknown_placeholder
# 2   knb-lter-jrn  210001002       76  Unknown_placeholder
# 3   knb-lter-jrn  210001003       79  Unknown_placeholder
# 14  knb-lter-jrn  210012001      139  Unknown_placeholder
# 15  knb-lter-jrn  210012002      127  Unknown_placeholder

# %%
# Concatenate these rows to our dataframe
df2 = pd.concat([df, df_rep])
print(df.shape)
df2.shape
# Out:
# (117, 9)
# (144, 9)

# %% [markdown]
# ## Prepare table for metabase

# %%
# Format the dataframe to look like the DataSetSites table in jrn_metabase
df2['EntitySortOrder'] = 0
df2['GeoCoverageSortOrder'] = 1
df_in = df2.loc[:,['datasetid','EntitySortOrder','SiteID','GeoCoverageSortOrder']]
df_in.head()
# Out:
#    datasetid  EntitySortOrder                     SiteID  GeoCoverageSortOrder
# 0        100                0  shrub_cover_raster_pkg100                     1
# 1  210001001                0                Bajada_West                     1
# 2  210001002                0                Bajada_West                     1
# 3  210001003                0                Bajada_West                     1
# 4  210002001                0                  NPP_Sites                     1

# %%
# Some of these are in the database already - remove from incoming table
print(len(df_in))
test = ((df_in.datasetid=='100') | (df_in.datasetid=='210001001') | 
         (df_in.datasetid=='210001002') | (df_in.datasetid=='210001003') |
         (df_in.datasetid=='210002001'))
df_in2 = df_in[~test]
len(df_in2)
# Out:
# 144
# 136

# %% [markdown]
# ## Now insert the table

# %%
# Establish database connection
sys.path.append('../')
import py2pg.connect as connect
conn = connect.connect('../jrn_metabase_dev.conn.json')

# %%
# Do a test query of the database
sql = 'select * from lter_metabase."DataSetSites";'
dat = pd.read_sql_query(sql, conn)

# %%
dat.head()
# Out:
#    DataSetID  EntitySortOrder                     SiteID  GeoCoverageSortOrder
# 0      99021                0                  ABUR_reef                     1
# 1      99021                0                  AQUE_reef                     1
# 2      99021                0                  MOHK_reef                     1
# 3        100                1  shrub_cover_raster_pkg100                     1
# 4  210001001                1                Bajada_West                     1

# %%
import py2pg.populate as pop

# %%
#Use function to load ent_in
pop.copy_from_file(conn, df_in2, 'lter_metabase."DataSetSites"') # copy the dataframe to SQL
# Close the database connection
conn.close()
# Out:
# copy_from_file() done
